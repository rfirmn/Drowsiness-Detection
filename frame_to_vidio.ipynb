# %%
import os
import subprocess

# 1. Tentukan direktori-direktori
# Sesuaikan ini dengan path yang benar di sistem Anda
BASE_DIR = "Data Slayer 3/test" 
OUTPUT_DIR = "Data Slayer 3/test_video" 
FPS = 30 # Karena 30 frame = 1 detik

# Pola yang benar untuk 01.jpg, 02.jpg, ..., 30.jpg
FRAME_PREFIX = "" 
FRAME_PADDING = "%02d" # Menggunakan 2 digit padding (01, 02, dst.)
FILE_EXTENSION = ".jpg"

# Buat direktori output jika belum ada
os.makedirs(OUTPUT_DIR, exist_ok=True)

print(f"Memulai konversi dengan pola input: {FRAME_PREFIX}{FRAME_PADDING}{FILE_EXTENSION}")
print("-" * 50)

# 2. Loop melalui setiap folder sequence
for seq_folder in os.listdir(BASE_DIR):
    seq_path = os.path.join(BASE_DIR, seq_folder)
    
    if os.path.isdir(seq_path) and not seq_folder.startswith('.'):
        
        frame_pattern = os.path.join(seq_path, f"{FRAME_PREFIX}{FRAME_PADDING}{FILE_EXTENSION}") 
        
        # Pengecekan cepat untuk frame pertama (01.jpg)
        test_frame_path = os.path.join(seq_path, "01.jpg")
        
        if not os.path.exists(test_frame_path):
            print(f"⚠️ Melewati folder {seq_folder}. Frame awal (01.jpg) tidak ditemukan di dalamnya.")
            continue 
            
        print(f"Memproses folder: {seq_folder}...")
        
        output_filename = f"{seq_folder}.mp4"
        output_path = os.path.join(OUTPUT_DIR, output_filename)
        
        # Perintah FFmpeg
        ffmpeg_command = [
            "ffmpeg",
            "-y", # Overwrite output files without asking
            "-framerate", str(FPS),
            "-i", frame_pattern, # Input: menggunakan pola %02d.jpg
            "-c:v", "libx264",
            "-pix_fmt", "yuv420p",
            "-r", str(FPS),
            output_path
        ]
        
        # 5. Jalankan perintah
        try:
            # Menggunakan subprocess.run() untuk menjalankan FFmpeg
            subprocess.run(ffmpeg_command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            print(f"✅ Berhasil membuat: {output_filename}")
        except subprocess.CalledProcessError as e:
            # Menangkap error jika FFmpeg gagal
            print(f"❌ Gagal memproses {seq_folder}. Error: {e.stderr.decode().strip().splitlines()[-1]}")
        except FileNotFoundError:
            print("❌ Error: FFmpeg tidak ditemukan. Pastikan sudah terinstal dan ada di PATH sistem.")

print("-" * 50)
print(f"Proses Konversi Selesai. Video-video baru tersimpan di: {OUTPUT_DIR}")
# Out:
# Memulai konversi dengan pola input: %02d.jpg
# --------------------------------------------------
# Memproses folder: test_seq_00096...
# ✅ Berhasil membuat: test_seq_00096.mp4
# Memproses folder: test_seq_00406...
# ✅ Berhasil membuat: test_seq_00406.mp4
# Memproses folder: test_seq_00250...
# ✅ Berhasil membuat: test_seq_00250.mp4
# Memproses folder: test_seq_00062...
# ✅ Berhasil membuat: test_seq_00062.mp4
# Memproses folder: test_seq_00439...
# ✅ Berhasil membuat: test_seq_00439.mp4
# Memproses folder: test_seq_00065...
# ✅ Berhasil membuat: test_seq_00065.mp4
# Memproses folder: test_seq_00257...
# ✅ Berhasil membuat: test_seq_00257.mp4
# Memproses folder: test_seq_00401...
# ✅ Berhasil membuat: test_seq_00401.mp4
# Memproses folder: test_seq_00091...
# ✅ Berhasil membuat: test_seq_00091.mp4
# Memproses folder: test_seq_00268...
# ✅ Berhasil membuat: test_seq_00268.mp4
# Memproses folder: test_seq_00437...
# ✅ Berhasil membuat: test_seq_00437.mp4
# Memproses folder: test_seq_00053...
# ✅ Berhasil membuat: test_seq_00053.mp4
# Memproses folder: test_seq_00261...
# ✅ Berhasil membuat: test_seq_00261.mp4
# Memproses folder: test_seq_00295...
# ✅ Berhasil membuat: test_seq_00295.mp4
# Memproses folder: test_seq_00408...
# ✅ Berhasil membuat: test_seq_00408.mp4
# Memproses folder: test_seq_00098...
# ✅ Berhasil membuat: test_seq_00098.mp4
# Memproses folder: test_seq_00292...
# ✅ Berhasil membuat: test_seq_00292.mp4
# Memproses folder: test_seq_00266...
# ✅ Berhasil membuat: test_seq_00266.mp4
# Memproses folder: test_seq_00054...
# ✅ Berhasil membuat: test_seq_00054.mp4
# Memproses folder: test_seq_00430...
# ✅ Berhasil membuat: test_seq_00430.mp4
# Memproses folder: test_seq_00602...
# ✅ Berhasil membuat: test_seq_00602.mp4
# Memproses folder: test_seq_00259...
# ✅ Berhasil membuat: test_seq_00259.mp4
# Memproses folder: test_seq_00490...
# ✅ Berhasil membuat: test_seq_00490.mp4
# Memproses folder: test_seq_00232...
# ✅ Berhasil membuat: test_seq_00232.mp4
# Memproses folder: test_seq_00464...
# ✅ Berhasil membuat: test_seq_00464.mp4
# Memproses folder: test_seq_00038...
# ✅ Berhasil membuat: test_seq_00038.mp4
# Memproses folder: test_seq_00463...
# ✅ Berhasil membuat: test_seq_00463.mp4
# Memproses folder: test_seq_00235...
# ✅ Berhasil membuat: test_seq_00235.mp4
# Memproses folder: test_seq_00007...
# ✅ Berhasil membuat: test_seq_00007.mp4
# Memproses folder: test_seq_00497...
# ✅ Berhasil membuat: test_seq_00497.mp4
# Memproses folder: test_seq_00203...
# ✅ Berhasil membuat: test_seq_00203.mp4
# Memproses folder: test_seq_00031...
# ✅ Berhasil membuat: test_seq_00031.mp4
# Memproses folder: test_seq_00455...
# ✅ Berhasil membuat: test_seq_00455.mp4
# Memproses folder: test_seq_00499...
# ✅ Berhasil membuat: test_seq_00499.mp4
# Memproses folder: test_seq_00009...
# ✅ Berhasil membuat: test_seq_00009.mp4
# Memproses folder: test_seq_00452...
# ✅ Berhasil membuat: test_seq_00452.mp4
# Memproses folder: test_seq_00036...
# ✅ Berhasil membuat: test_seq_00036.mp4
# Memproses folder: test_seq_00204...
# ✅ Berhasil membuat: test_seq_00204.mp4
# Memproses folder: test_seq_00055...
# ✅ Berhasil membuat: test_seq_00055.mp4
# Memproses folder: test_seq_00267...
# ✅ Berhasil membuat: test_seq_00267.mp4
# Memproses folder: test_seq_00431...
# ✅ Berhasil membuat: test_seq_00431.mp4
# Memproses folder: test_seq_00293...
# ✅ Berhasil membuat: test_seq_00293.mp4
# Memproses folder: test_seq_00258...
# ✅ Berhasil membuat: test_seq_00258.mp4
# Memproses folder: test_seq_00294...
# ✅ Berhasil membuat: test_seq_00294.mp4
# Memproses folder: test_seq_00436...
# ✅ Berhasil membuat: test_seq_00436.mp4
# Memproses folder: test_seq_00260...
# ✅ Berhasil membuat: test_seq_00260.mp4
# Memproses folder: test_seq_00052...
# ✅ Berhasil membuat: test_seq_00052.mp4
# Memproses folder: test_seq_00099...
# ✅ Berhasil membuat: test_seq_00099.mp4
# Memproses folder: test_seq_00409...
# ✅ Berhasil membuat: test_seq_00409.mp4
# Memproses folder: test_seq_00090...
# ✅ Berhasil membuat: test_seq_00090.mp4
# Memproses folder: test_seq_00256...
# ✅ Berhasil membuat: test_seq_00256.mp4
# Memproses folder: test_seq_00064...
# ✅ Berhasil membuat: test_seq_00064.mp4
# Memproses folder: test_seq_00400...
# ✅ Berhasil membuat: test_seq_00400.mp4
# Memproses folder: test_seq_00269...
# ✅ Berhasil membuat: test_seq_00269.mp4
# Memproses folder: test_seq_00407...
# ✅ Berhasil membuat: test_seq_00407.mp4
# Memproses folder: test_seq_00063...
# ✅ Berhasil membuat: test_seq_00063.mp4
# Memproses folder: test_seq_00251...
# ✅ Berhasil membuat: test_seq_00251.mp4
# Memproses folder: test_seq_00097...
# ✅ Berhasil membuat: test_seq_00097.mp4
# Memproses folder: test_seq_00438...
# ✅ Berhasil membuat: test_seq_00438.mp4
# Memproses folder: test_seq_00008...
# ✅ Berhasil membuat: test_seq_00008.mp4
# Memproses folder: test_seq_00498...
# ✅ Berhasil membuat: test_seq_00498.mp4
# Memproses folder: test_seq_00453...
# ✅ Berhasil membuat: test_seq_00453.mp4
# Memproses folder: test_seq_00205...
# ✅ Berhasil membuat: test_seq_00205.mp4
# Memproses folder: test_seq_00037...
# ✅ Berhasil membuat: test_seq_00037.mp4
# Memproses folder: test_seq_00030...
# ✅ Berhasil membuat: test_seq_00030.mp4
# Memproses folder: test_seq_00202...
# ✅ Berhasil membuat: test_seq_00202.mp4
# Memproses folder: test_seq_00454...
# ✅ Berhasil membuat: test_seq_00454.mp4
# Memproses folder: test_seq_00039...
# ✅ Berhasil membuat: test_seq_00039.mp4
# Memproses folder: test_seq_00496...
# ✅ Berhasil membuat: test_seq_00496.mp4
# Memproses folder: test_seq_00462...
# ✅ Berhasil membuat: test_seq_00462.mp4
# Memproses folder: test_seq_00006...
# ✅ Berhasil membuat: test_seq_00006.mp4
# Memproses folder: test_seq_00234...
# ✅ Berhasil membuat: test_seq_00234.mp4
# Memproses folder: test_seq_00233...
# ✅ Berhasil membuat: test_seq_00233.mp4
# Memproses folder: test_seq_00001...
# ✅ Berhasil membuat: test_seq_00001.mp4
# Memproses folder: test_seq_00465...
# ✅ Berhasil membuat: test_seq_00465.mp4
# Memproses folder: test_seq_00491...
# ✅ Berhasil membuat: test_seq_00491.mp4
# Memproses folder: test_seq_00187...
# ✅ Berhasil membuat: test_seq_00187.mp4
# Memproses folder: test_seq_00517...
# ✅ Berhasil membuat: test_seq_00517.mp4
# Memproses folder: test_seq_00341...
# ✅ Berhasil membuat: test_seq_00341.mp4
# Memproses folder: test_seq_00173...
# ✅ Berhasil membuat: test_seq_00173.mp4
# Memproses folder: test_seq_00528...
# ✅ Berhasil membuat: test_seq_00528.mp4
# Memproses folder: test_seq_00174...
# ✅ Berhasil membuat: test_seq_00174.mp4
# Memproses folder: test_seq_00346...
# ✅ Berhasil membuat: test_seq_00346.mp4
# Memproses folder: test_seq_00510...
# ✅ Berhasil membuat: test_seq_00510.mp4
# Memproses folder: test_seq_00180...
# ✅ Berhasil membuat: test_seq_00180.mp4
# Memproses folder: test_seq_00379...
# ✅ Berhasil membuat: test_seq_00379.mp4
# Memproses folder: test_seq_00526...
# ✅ Berhasil membuat: test_seq_00526.mp4
# Memproses folder: test_seq_00142...
# ✅ Berhasil membuat: test_seq_00142.mp4
# Memproses folder: test_seq_00370...
# ✅ Berhasil membuat: test_seq_00370.mp4
# Memproses folder: test_seq_00384...
# ✅ Berhasil membuat: test_seq_00384.mp4
# Memproses folder: test_seq_00519...
# ✅ Berhasil membuat: test_seq_00519.mp4
# Memproses folder: test_seq_00189...
# ✅ Berhasil membuat: test_seq_00189.mp4
# Memproses folder: test_seq_00383...
# ✅ Berhasil membuat: test_seq_00383.mp4
# Memproses folder: test_seq_00377...
# ✅ Berhasil membuat: test_seq_00377.mp4
# Memproses folder: test_seq_00145...
# ✅ Berhasil membuat: test_seq_00145.mp4
# Memproses folder: test_seq_00521...
# ✅ Berhasil membuat: test_seq_00521.mp4
# Memproses folder: test_seq_00348...
# ✅ Berhasil membuat: test_seq_00348.mp4
# Memproses folder: test_seq_00581...
# ✅ Berhasil membuat: test_seq_00581.mp4
# Memproses folder: test_seq_00111...
# ✅ Berhasil membuat: test_seq_00111.mp4
# Memproses folder: test_seq_00323...
# ✅ Berhasil membuat: test_seq_00323.mp4
# Memproses folder: test_seq_00575...
# ✅ Berhasil membuat: test_seq_00575.mp4
# Memproses folder: test_seq_00129...
# ✅ Berhasil membuat: test_seq_00129.mp4
# Memproses folder: test_seq_00572...
# ✅ Berhasil membuat: test_seq_00572.mp4
# Memproses folder: test_seq_00324...
# ✅ Berhasil membuat: test_seq_00324.mp4
# Memproses folder: test_seq_00116...
# ✅ Berhasil membuat: test_seq_00116.mp4
# Memproses folder: test_seq_00586...
# ✅ Berhasil membuat: test_seq_00586.mp4
# Memproses folder: test_seq_00312...
# ✅ Berhasil membuat: test_seq_00312.mp4
# Memproses folder: test_seq_00120...
# ✅ Berhasil membuat: test_seq_00120.mp4
# Memproses folder: test_seq_00544...
# ✅ Berhasil membuat: test_seq_00544.mp4
# Memproses folder: test_seq_00588...
# ✅ Berhasil membuat: test_seq_00588.mp4
# Memproses folder: test_seq_00118...
# ✅ Berhasil membuat: test_seq_00118.mp4
# Memproses folder: test_seq_00543...
# ✅ Berhasil membuat: test_seq_00543.mp4
# Memproses folder: test_seq_00127...
# ✅ Berhasil membuat: test_seq_00127.mp4
# Memproses folder: test_seq_00315...
# ✅ Berhasil membuat: test_seq_00315.mp4
# Memproses folder: test_seq_00144...
# ✅ Berhasil membuat: test_seq_00144.mp4
# Memproses folder: test_seq_00376...
# ✅ Berhasil membuat: test_seq_00376.mp4
# Memproses folder: test_seq_00520...
# ✅ Berhasil membuat: test_seq_00520.mp4
# Memproses folder: test_seq_00382...
# ✅ Berhasil membuat: test_seq_00382.mp4
# Memproses folder: test_seq_00349...
# ✅ Berhasil membuat: test_seq_00349.mp4
# Memproses folder: test_seq_00385...
# ✅ Berhasil membuat: test_seq_00385.mp4
# Memproses folder: test_seq_00527...
# ✅ Berhasil membuat: test_seq_00527.mp4
# Memproses folder: test_seq_00371...
# ✅ Berhasil membuat: test_seq_00371.mp4
# Memproses folder: test_seq_00143...
# ✅ Berhasil membuat: test_seq_00143.mp4
# Memproses folder: test_seq_00188...
# ✅ Berhasil membuat: test_seq_00188.mp4
# Memproses folder: test_seq_00518...
# ✅ Berhasil membuat: test_seq_00518.mp4
# Memproses folder: test_seq_00181...
# ✅ Berhasil membuat: test_seq_00181.mp4
# Memproses folder: test_seq_00347...
# ✅ Berhasil membuat: test_seq_00347.mp4
# Memproses folder: test_seq_00175...
# ✅ Berhasil membuat: test_seq_00175.mp4
# Memproses folder: test_seq_00511...
# ✅ Berhasil membuat: test_seq_00511.mp4
# Memproses folder: test_seq_00378...
# ✅ Berhasil membuat: test_seq_00378.mp4
# Memproses folder: test_seq_00516...
# ✅ Berhasil membuat: test_seq_00516.mp4
# Memproses folder: test_seq_00172...
# ✅ Berhasil membuat: test_seq_00172.mp4
# Memproses folder: test_seq_00340...
# ✅ Berhasil membuat: test_seq_00340.mp4
# Memproses folder: test_seq_00186...
# ✅ Berhasil membuat: test_seq_00186.mp4
# Memproses folder: test_seq_00529...
# ✅ Berhasil membuat: test_seq_00529.mp4
# Memproses folder: test_seq_00119...
# ✅ Berhasil membuat: test_seq_00119.mp4
# Memproses folder: test_seq_00589...
# ✅ Berhasil membuat: test_seq_00589.mp4
# Memproses folder: test_seq_00542...
# ✅ Berhasil membuat: test_seq_00542.mp4
# Memproses folder: test_seq_00314...
# ✅ Berhasil membuat: test_seq_00314.mp4
# Memproses folder: test_seq_00126...
# ✅ Berhasil membuat: test_seq_00126.mp4
# Memproses folder: test_seq_00121...
# ✅ Berhasil membuat: test_seq_00121.mp4
# Memproses folder: test_seq_00313...
# ✅ Berhasil membuat: test_seq_00313.mp4
# Memproses folder: test_seq_00545...
# ✅ Berhasil membuat: test_seq_00545.mp4
# Memproses folder: test_seq_00128...
# ✅ Berhasil membuat: test_seq_00128.mp4
# Memproses folder: test_seq_00587...
# ✅ Berhasil membuat: test_seq_00587.mp4
# Memproses folder: test_seq_00573...
# ✅ Berhasil membuat: test_seq_00573.mp4
# Memproses folder: test_seq_00117...
# ✅ Berhasil membuat: test_seq_00117.mp4
# Memproses folder: test_seq_00325...
# ✅ Berhasil membuat: test_seq_00325.mp4
# Memproses folder: test_seq_00322...
# ✅ Berhasil membuat: test_seq_00322.mp4
# Memproses folder: test_seq_00110...
# ✅ Berhasil membuat: test_seq_00110.mp4
# Memproses folder: test_seq_00574...
# ✅ Berhasil membuat: test_seq_00574.mp4
# Memproses folder: test_seq_00580...
# ✅ Berhasil membuat: test_seq_00580.mp4
# Memproses folder: test_seq_00556...
# ✅ Berhasil membuat: test_seq_00556.mp4
# Memproses folder: test_seq_00132...
# ✅ Berhasil membuat: test_seq_00132.mp4
# Memproses folder: test_seq_00300...
# ✅ Berhasil membuat: test_seq_00300.mp4
# Memproses folder: test_seq_00569...
# ✅ Berhasil membuat: test_seq_00569.mp4
# Memproses folder: test_seq_00307...
# ✅ Berhasil membuat: test_seq_00307.mp4
# Memproses folder: test_seq_00135...
# ✅ Berhasil membuat: test_seq_00135.mp4
# Memproses folder: test_seq_00551...
# ✅ Berhasil membuat: test_seq_00551.mp4
# Memproses folder: test_seq_00338...
# ✅ Berhasil membuat: test_seq_00338.mp4
# Memproses folder: test_seq_00593...
# ✅ Berhasil membuat: test_seq_00593.mp4
# Memproses folder: test_seq_00567...
# ✅ Berhasil membuat: test_seq_00567.mp4
# Memproses folder: test_seq_00331...
# ✅ Berhasil membuat: test_seq_00331.mp4
# Memproses folder: test_seq_00103...
# ✅ Berhasil membuat: test_seq_00103.mp4
# Memproses folder: test_seq_00558...
# ✅ Berhasil membuat: test_seq_00558.mp4
# Memproses folder: test_seq_00104...
# ✅ Berhasil membuat: test_seq_00104.mp4
# Memproses folder: test_seq_00336...
# ✅ Berhasil membuat: test_seq_00336.mp4
# Memproses folder: test_seq_00560...
# ✅ Berhasil membuat: test_seq_00560.mp4
# Memproses folder: test_seq_00594...
# ✅ Berhasil membuat: test_seq_00594.mp4
# Memproses folder: test_seq_00309...
# ✅ Berhasil membuat: test_seq_00309.mp4
# Memproses folder: test_seq_00362...
# ✅ Berhasil membuat: test_seq_00362.mp4
# Memproses folder: test_seq_00150...
# ✅ Berhasil membuat: test_seq_00150.mp4
# Memproses folder: test_seq_00534...
# ✅ Berhasil membuat: test_seq_00534.mp4
# Memproses folder: test_seq_00396...
# ✅ Berhasil membuat: test_seq_00396.mp4
# Memproses folder: test_seq_00168...
# ✅ Berhasil membuat: test_seq_00168.mp4
# Memproses folder: test_seq_00391...
# ✅ Berhasil membuat: test_seq_00391.mp4
# Memproses folder: test_seq_00533...
# ✅ Berhasil membuat: test_seq_00533.mp4
# Memproses folder: test_seq_00157...
# ✅ Berhasil membuat: test_seq_00157.mp4
# Memproses folder: test_seq_00365...
# ✅ Berhasil membuat: test_seq_00365.mp4
# Memproses folder: test_seq_00398...
# ✅ Berhasil membuat: test_seq_00398.mp4
# Memproses folder: test_seq_00195...
# ✅ Berhasil membuat: test_seq_00195.mp4
# Memproses folder: test_seq_00161...
# ✅ Berhasil membuat: test_seq_00161.mp4
# Memproses folder: test_seq_00353...
# ✅ Berhasil membuat: test_seq_00353.mp4
# Memproses folder: test_seq_00505...
# ✅ Berhasil membuat: test_seq_00505.mp4
# Memproses folder: test_seq_00159...
# ✅ Berhasil membuat: test_seq_00159.mp4
# Memproses folder: test_seq_00502...
# ✅ Berhasil membuat: test_seq_00502.mp4
# Memproses folder: test_seq_00354...
# ✅ Berhasil membuat: test_seq_00354.mp4
# Memproses folder: test_seq_00166...
# ✅ Berhasil membuat: test_seq_00166.mp4
# Memproses folder: test_seq_00192...
# ✅ Berhasil membuat: test_seq_00192.mp4
# Memproses folder: test_seq_00595...
# ✅ Berhasil membuat: test_seq_00595.mp4
# Memproses folder: test_seq_00337...
# ✅ Berhasil membuat: test_seq_00337.mp4
# Memproses folder: test_seq_00105...
# ✅ Berhasil membuat: test_seq_00105.mp4
# Memproses folder: test_seq_00561...
# ✅ Berhasil membuat: test_seq_00561.mp4
# Memproses folder: test_seq_00308...
# ✅ Berhasil membuat: test_seq_00308.mp4
# Memproses folder: test_seq_00566...
# ✅ Berhasil membuat: test_seq_00566.mp4
# Memproses folder: test_seq_00102...
# ✅ Berhasil membuat: test_seq_00102.mp4
# Memproses folder: test_seq_00330...
# ✅ Berhasil membuat: test_seq_00330.mp4
# Memproses folder: test_seq_00592...
# ✅ Berhasil membuat: test_seq_00592.mp4
# Memproses folder: test_seq_00559...
# ✅ Berhasil membuat: test_seq_00559.mp4
# Memproses folder: test_seq_00134...
# ✅ Berhasil membuat: test_seq_00134.mp4
# Memproses folder: test_seq_00306...
# ✅ Berhasil membuat: test_seq_00306.mp4
# Memproses folder: test_seq_00550...
# ✅ Berhasil membuat: test_seq_00550.mp4
# Memproses folder: test_seq_00339...
# ✅ Berhasil membuat: test_seq_00339.mp4
# Memproses folder: test_seq_00557...
# ✅ Berhasil membuat: test_seq_00557.mp4
# Memproses folder: test_seq_00301...
# ✅ Berhasil membuat: test_seq_00301.mp4
# Memproses folder: test_seq_00133...
# ✅ Berhasil membuat: test_seq_00133.mp4
# Memproses folder: test_seq_00568...
# ✅ Berhasil membuat: test_seq_00568.mp4
# Memproses folder: test_seq_00158...
# ✅ Berhasil membuat: test_seq_00158.mp4
# Memproses folder: test_seq_00193...
# ✅ Berhasil membuat: test_seq_00193.mp4
# Memproses folder: test_seq_00503...
# ✅ Berhasil membuat: test_seq_00503.mp4
# Memproses folder: test_seq_00167...
# ✅ Berhasil membuat: test_seq_00167.mp4
# Memproses folder: test_seq_00355...
# ✅ Berhasil membuat: test_seq_00355.mp4
# Memproses folder: test_seq_00399...
# ✅ Berhasil membuat: test_seq_00399.mp4
# Memproses folder: test_seq_00352...
# ✅ Berhasil membuat: test_seq_00352.mp4
# Memproses folder: test_seq_00160...
# ✅ Berhasil membuat: test_seq_00160.mp4
# Memproses folder: test_seq_00504...
# ✅ Berhasil membuat: test_seq_00504.mp4
# Memproses folder: test_seq_00194...
# ✅ Berhasil membuat: test_seq_00194.mp4
# Memproses folder: test_seq_00169...
# ✅ Berhasil membuat: test_seq_00169.mp4
# Memproses folder: test_seq_00532...
# ✅ Berhasil membuat: test_seq_00532.mp4
# Memproses folder: test_seq_00364...
# ✅ Berhasil membuat: test_seq_00364.mp4
# Memproses folder: test_seq_00156...
# ✅ Berhasil membuat: test_seq_00156.mp4
# Memproses folder: test_seq_00390...
# ✅ Berhasil membuat: test_seq_00390.mp4
# Memproses folder: test_seq_00397...
# ✅ Berhasil membuat: test_seq_00397.mp4
# Memproses folder: test_seq_00151...
# ✅ Berhasil membuat: test_seq_00151.mp4
# Memproses folder: test_seq_00363...
# ✅ Berhasil membuat: test_seq_00363.mp4
# Memproses folder: test_seq_00535...
# ✅ Berhasil membuat: test_seq_00535.mp4
# Memproses folder: test_seq_00447...
# ✅ Berhasil membuat: test_seq_00447.mp4
# Memproses folder: test_seq_00023...
# ✅ Berhasil membuat: test_seq_00023.mp4
# Memproses folder: test_seq_00211...
# ✅ Berhasil membuat: test_seq_00211.mp4
# Memproses folder: test_seq_00478...
# ✅ Berhasil membuat: test_seq_00478.mp4
# Memproses folder: test_seq_00216...
# ✅ Berhasil membuat: test_seq_00216.mp4
# Memproses folder: test_seq_00024...
# ✅ Berhasil membuat: test_seq_00024.mp4
# Memproses folder: test_seq_00440...
# ✅ Berhasil membuat: test_seq_00440.mp4
# Memproses folder: test_seq_00229...
# ✅ Berhasil membuat: test_seq_00229.mp4
# Memproses folder: test_seq_00482...
# ✅ Berhasil membuat: test_seq_00482.mp4
# Memproses folder: test_seq_00476...
# ✅ Berhasil membuat: test_seq_00476.mp4
# Memproses folder: test_seq_00220...
# ✅ Berhasil membuat: test_seq_00220.mp4
# Memproses folder: test_seq_00012...
# ✅ Berhasil membuat: test_seq_00012.mp4
# Memproses folder: test_seq_00449...
# ✅ Berhasil membuat: test_seq_00449.mp4
# Memproses folder: test_seq_00015...
# ✅ Berhasil membuat: test_seq_00015.mp4
# Memproses folder: test_seq_00227...
# ✅ Berhasil membuat: test_seq_00227.mp4
# Memproses folder: test_seq_00471...
# ✅ Berhasil membuat: test_seq_00471.mp4
# Memproses folder: test_seq_00485...
# ✅ Berhasil membuat: test_seq_00485.mp4
# Memproses folder: test_seq_00218...
# ✅ Berhasil membuat: test_seq_00218.mp4
# Memproses folder: test_seq_00273...
# ✅ Berhasil membuat: test_seq_00273.mp4
# Memproses folder: test_seq_00041...
# ✅ Berhasil membuat: test_seq_00041.mp4
# Memproses folder: test_seq_00425...
# ✅ Berhasil membuat: test_seq_00425.mp4
# Memproses folder: test_seq_00287...
# ✅ Berhasil membuat: test_seq_00287.mp4
# Memproses folder: test_seq_00079...
# ✅ Berhasil membuat: test_seq_00079.mp4
# Memproses folder: test_seq_00280...
# ✅ Berhasil membuat: test_seq_00280.mp4
# Memproses folder: test_seq_00422...
# ✅ Berhasil membuat: test_seq_00422.mp4
# Memproses folder: test_seq_00046...
# ✅ Berhasil membuat: test_seq_00046.mp4
# Memproses folder: test_seq_00274...
# ✅ Berhasil membuat: test_seq_00274.mp4
# Memproses folder: test_seq_00289...
# ✅ Berhasil membuat: test_seq_00289.mp4
# Memproses folder: test_seq_00084...
# ✅ Berhasil membuat: test_seq_00084.mp4
# Memproses folder: test_seq_00070...
# ✅ Berhasil membuat: test_seq_00070.mp4
# Memproses folder: test_seq_00242...
# ✅ Berhasil membuat: test_seq_00242.mp4
# Memproses folder: test_seq_00414...
# ✅ Berhasil membuat: test_seq_00414.mp4
# Memproses folder: test_seq_00048...
# ✅ Berhasil membuat: test_seq_00048.mp4
# Memproses folder: test_seq_00413...
# ✅ Berhasil membuat: test_seq_00413.mp4
# Memproses folder: test_seq_00245...
# ✅ Berhasil membuat: test_seq_00245.mp4
# Memproses folder: test_seq_00077...
# ✅ Berhasil membuat: test_seq_00077.mp4
# Memproses folder: test_seq_00083...
# ✅ Berhasil membuat: test_seq_00083.mp4
# Memproses folder: test_seq_00484...
# ✅ Berhasil membuat: test_seq_00484.mp4
# Memproses folder: test_seq_00226...
# ✅ Berhasil membuat: test_seq_00226.mp4
# Memproses folder: test_seq_00014...
# ✅ Berhasil membuat: test_seq_00014.mp4
# Memproses folder: test_seq_00470...
# ✅ Berhasil membuat: test_seq_00470.mp4
# Memproses folder: test_seq_00219...
# ✅ Berhasil membuat: test_seq_00219.mp4
# Memproses folder: test_seq_00477...
# ✅ Berhasil membuat: test_seq_00477.mp4
# Memproses folder: test_seq_00013...
# ✅ Berhasil membuat: test_seq_00013.mp4
# Memproses folder: test_seq_00221...
# ✅ Berhasil membuat: test_seq_00221.mp4
# Memproses folder: test_seq_00483...
# ✅ Berhasil membuat: test_seq_00483.mp4
# Memproses folder: test_seq_00448...
# ✅ Berhasil membuat: test_seq_00448.mp4
# Memproses folder: test_seq_00025...
# ✅ Berhasil membuat: test_seq_00025.mp4
# Memproses folder: test_seq_00217...
# ✅ Berhasil membuat: test_seq_00217.mp4
# Memproses folder: test_seq_00441...
# ✅ Berhasil membuat: test_seq_00441.mp4
# Memproses folder: test_seq_00228...
# ✅ Berhasil membuat: test_seq_00228.mp4
# Memproses folder: test_seq_00446...
# ✅ Berhasil membuat: test_seq_00446.mp4
# Memproses folder: test_seq_00210...
# ✅ Berhasil membuat: test_seq_00210.mp4
# Memproses folder: test_seq_00022...
# ✅ Berhasil membuat: test_seq_00022.mp4
# Memproses folder: test_seq_00479...
# ✅ Berhasil membuat: test_seq_00479.mp4
# Memproses folder: test_seq_00049...
# ✅ Berhasil membuat: test_seq_00049.mp4
# Memproses folder: test_seq_00082...
# ✅ Berhasil membuat: test_seq_00082.mp4
# Memproses folder: test_seq_00412...
# ✅ Berhasil membuat: test_seq_00412.mp4
# Memproses folder: test_seq_00076...
# ✅ Berhasil membuat: test_seq_00076.mp4
# Memproses folder: test_seq_00244...
# ✅ Berhasil membuat: test_seq_00244.mp4
# Memproses folder: test_seq_00288...
# ✅ Berhasil membuat: test_seq_00288.mp4
# Memproses folder: test_seq_00243...
# ✅ Berhasil membuat: test_seq_00243.mp4
# Memproses folder: test_seq_00071...
# ✅ Berhasil membuat: test_seq_00071.mp4
# Memproses folder: test_seq_00415...
# ✅ Berhasil membuat: test_seq_00415.mp4
# Memproses folder: test_seq_00085...
# ✅ Berhasil membuat: test_seq_00085.mp4
# Memproses folder: test_seq_00078...
# ✅ Berhasil membuat: test_seq_00078.mp4
# Memproses folder: test_seq_00423...
# ✅ Berhasil membuat: test_seq_00423.mp4
# Memproses folder: test_seq_00275...
# ✅ Berhasil membuat: test_seq_00275.mp4
# Memproses folder: test_seq_00047...
# ✅ Berhasil membuat: test_seq_00047.mp4
# Memproses folder: test_seq_00281...
# ✅ Berhasil membuat: test_seq_00281.mp4
# Memproses folder: test_seq_00286...
# ✅ Berhasil membuat: test_seq_00286.mp4
# Memproses folder: test_seq_00040...
# ✅ Berhasil membuat: test_seq_00040.mp4
# Memproses folder: test_seq_00272...
# ✅ Berhasil membuat: test_seq_00272.mp4
# Memproses folder: test_seq_00424...
# ✅ Berhasil membuat: test_seq_00424.mp4
# Memproses folder: test_seq_00209...
# ✅ Berhasil membuat: test_seq_00209.mp4
# Memproses folder: test_seq_00460...
# ✅ Berhasil membuat: test_seq_00460.mp4
# Memproses folder: test_seq_00004...
# ✅ Berhasil membuat: test_seq_00004.mp4
# Memproses folder: test_seq_00236...
# ✅ Berhasil membuat: test_seq_00236.mp4
# Memproses folder: test_seq_00494...
# ✅ Berhasil membuat: test_seq_00494.mp4
# Memproses folder: test_seq_00458...
# ✅ Berhasil membuat: test_seq_00458.mp4
# Memproses folder: test_seq_00493...
# ✅ Berhasil membuat: test_seq_00493.mp4
# Memproses folder: test_seq_00231...
# ✅ Berhasil membuat: test_seq_00231.mp4
# Memproses folder: test_seq_00003...
# ✅ Berhasil membuat: test_seq_00003.mp4
# Memproses folder: test_seq_00467...
# ✅ Berhasil membuat: test_seq_00467.mp4
# Memproses folder: test_seq_00238...
# ✅ Berhasil membuat: test_seq_00238.mp4
# Memproses folder: test_seq_00451...
# ✅ Berhasil membuat: test_seq_00451.mp4
# Memproses folder: test_seq_00207...
# ✅ Berhasil membuat: test_seq_00207.mp4
# Memproses folder: test_seq_00035...
# ✅ Berhasil membuat: test_seq_00035.mp4
# Memproses folder: test_seq_00469...
# ✅ Berhasil membuat: test_seq_00469.mp4
# Memproses folder: test_seq_00032...
# ✅ Berhasil membuat: test_seq_00032.mp4
# Memproses folder: test_seq_00200...
# ✅ Berhasil membuat: test_seq_00200.mp4
# Memproses folder: test_seq_00456...
# ✅ Berhasil membuat: test_seq_00456.mp4
# Memproses folder: test_seq_00254...
# ✅ Berhasil membuat: test_seq_00254.mp4
# Memproses folder: test_seq_00066...
# ✅ Berhasil membuat: test_seq_00066.mp4
# Memproses folder: test_seq_00402...
# ✅ Berhasil membuat: test_seq_00402.mp4
# Memproses folder: test_seq_00092...
# ✅ Berhasil membuat: test_seq_00092.mp4
# Memproses folder: test_seq_00059...
# ✅ Berhasil membuat: test_seq_00059.mp4
# Memproses folder: test_seq_00095...
# ✅ Berhasil membuat: test_seq_00095.mp4
# Memproses folder: test_seq_00405...
# ✅ Berhasil membuat: test_seq_00405.mp4
# Memproses folder: test_seq_00061...
# ✅ Berhasil membuat: test_seq_00061.mp4
# Memproses folder: test_seq_00253...
# ✅ Berhasil membuat: test_seq_00253.mp4
# Memproses folder: test_seq_00298...
# ✅ Berhasil membuat: test_seq_00298.mp4
# Memproses folder: test_seq_00291...
# ✅ Berhasil membuat: test_seq_00291.mp4
# Memproses folder: test_seq_00057...
# ✅ Berhasil membuat: test_seq_00057.mp4
# Memproses folder: test_seq_00265...
# ✅ Berhasil membuat: test_seq_00265.mp4
# Memproses folder: test_seq_00601...
# ✅ Berhasil membuat: test_seq_00601.mp4
# Memproses folder: test_seq_00433...
# ✅ Berhasil membuat: test_seq_00433.mp4
# Memproses folder: test_seq_00068...
# ✅ Berhasil membuat: test_seq_00068.mp4
# Memproses folder: test_seq_00434...
# ✅ Berhasil membuat: test_seq_00434.mp4
# Memproses folder: test_seq_00262...
# ✅ Berhasil membuat: test_seq_00262.mp4
# Memproses folder: test_seq_00050...
# ✅ Berhasil membuat: test_seq_00050.mp4
# Memproses folder: test_seq_00296...
# ✅ Berhasil membuat: test_seq_00296.mp4
# Memproses folder: test_seq_00468...
# ✅ Berhasil membuat: test_seq_00468.mp4
# Memproses folder: test_seq_00201...
# ✅ Berhasil membuat: test_seq_00201.mp4
# Memproses folder: test_seq_00033...
# ✅ Berhasil membuat: test_seq_00033.mp4
# Memproses folder: test_seq_00457...
# ✅ Berhasil membuat: test_seq_00457.mp4
# Memproses folder: test_seq_00239...
# ✅ Berhasil membuat: test_seq_00239.mp4
# Memproses folder: test_seq_00450...
# ✅ Berhasil membuat: test_seq_00450.mp4
# Memproses folder: test_seq_00034...
# ✅ Berhasil membuat: test_seq_00034.mp4
# Memproses folder: test_seq_00206...
# ✅ Berhasil membuat: test_seq_00206.mp4
# Memproses folder: test_seq_00459...
# ✅ Berhasil membuat: test_seq_00459.mp4
# Memproses folder: test_seq_00002...
# ✅ Berhasil membuat: test_seq_00002.mp4
# Memproses folder: test_seq_00230...
# ✅ Berhasil membuat: test_seq_00230.mp4
# Memproses folder: test_seq_00466...
# ✅ Berhasil membuat: test_seq_00466.mp4
# Memproses folder: test_seq_00492...
# ✅ Berhasil membuat: test_seq_00492.mp4
# Memproses folder: test_seq_00208...
# ✅ Berhasil membuat: test_seq_00208.mp4
# Memproses folder: test_seq_00495...
# ✅ Berhasil membuat: test_seq_00495.mp4
# Memproses folder: test_seq_00461...
# ✅ Berhasil membuat: test_seq_00461.mp4
# Memproses folder: test_seq_00237...
# ✅ Berhasil membuat: test_seq_00237.mp4
# Memproses folder: test_seq_00005...
# ✅ Berhasil membuat: test_seq_00005.mp4
# Memproses folder: test_seq_00297...
# ✅ Berhasil membuat: test_seq_00297.mp4
# Memproses folder: test_seq_00435...
# ✅ Berhasil membuat: test_seq_00435.mp4
# Memproses folder: test_seq_00051...
# ✅ Berhasil membuat: test_seq_00051.mp4
# Memproses folder: test_seq_00263...
# ✅ Berhasil membuat: test_seq_00263.mp4
# Memproses folder: test_seq_00264...
# ✅ Berhasil membuat: test_seq_00264.mp4
# Memproses folder: test_seq_00056...
# ✅ Berhasil membuat: test_seq_00056.mp4
# Memproses folder: test_seq_00432...
# ✅ Berhasil membuat: test_seq_00432.mp4
# Memproses folder: test_seq_00600...
# ✅ Berhasil membuat: test_seq_00600.mp4
# Memproses folder: test_seq_00290...
# ✅ Berhasil membuat: test_seq_00290.mp4
# Memproses folder: test_seq_00069...
# ✅ Berhasil membuat: test_seq_00069.mp4
# Memproses folder: test_seq_00404...
# ✅ Berhasil membuat: test_seq_00404.mp4
# Memproses folder: test_seq_00252...
# ✅ Berhasil membuat: test_seq_00252.mp4
# Memproses folder: test_seq_00060...
# ✅ Berhasil membuat: test_seq_00060.mp4
# Memproses folder: test_seq_00094...
# ✅ Berhasil membuat: test_seq_00094.mp4
# Memproses folder: test_seq_00299...
# ✅ Berhasil membuat: test_seq_00299.mp4
# Memproses folder: test_seq_00093...
# ✅ Berhasil membuat: test_seq_00093.mp4
# Memproses folder: test_seq_00067...
# ✅ Berhasil membuat: test_seq_00067.mp4
# Memproses folder: test_seq_00255...
# ✅ Berhasil membuat: test_seq_00255.mp4
# Memproses folder: test_seq_00403...
# ✅ Berhasil membuat: test_seq_00403.mp4
# Memproses folder: test_seq_00058...
# ✅ Berhasil membuat: test_seq_00058.mp4
# Memproses folder: test_seq_00318...
# ✅ Berhasil membuat: test_seq_00318.mp4
# Memproses folder: test_seq_00571...
# ✅ Berhasil membuat: test_seq_00571.mp4
# Memproses folder: test_seq_00115...
# ✅ Berhasil membuat: test_seq_00115.mp4
# Memproses folder: test_seq_00327...
# ✅ Berhasil membuat: test_seq_00327.mp4
# Memproses folder: test_seq_00585...
# ✅ Berhasil membuat: test_seq_00585.mp4
# Memproses folder: test_seq_00549...
# ✅ Berhasil membuat: test_seq_00549.mp4
# Memproses folder: test_seq_00582...
# ✅ Berhasil membuat: test_seq_00582.mp4
# Memproses folder: test_seq_00320...
# ✅ Berhasil membuat: test_seq_00320.mp4
# Memproses folder: test_seq_00112...
# ✅ Berhasil membuat: test_seq_00112.mp4
# Memproses folder: test_seq_00576...
# ✅ Berhasil membuat: test_seq_00576.mp4
# Memproses folder: test_seq_00329...
# ✅ Berhasil membuat: test_seq_00329.mp4
# Memproses folder: test_seq_00540...
# ✅ Berhasil membuat: test_seq_00540.mp4
# Memproses folder: test_seq_00316...
# ✅ Berhasil membuat: test_seq_00316.mp4
# Memproses folder: test_seq_00124...
# ✅ Berhasil membuat: test_seq_00124.mp4
# Memproses folder: test_seq_00578...
# ✅ Berhasil membuat: test_seq_00578.mp4
# Memproses folder: test_seq_00123...
# ✅ Berhasil membuat: test_seq_00123.mp4
# Memproses folder: test_seq_00311...
# ✅ Berhasil membuat: test_seq_00311.mp4
# Memproses folder: test_seq_00547...
# ✅ Berhasil membuat: test_seq_00547.mp4
# Memproses folder: test_seq_00345...
# ✅ Berhasil membuat: test_seq_00345.mp4
# Memproses folder: test_seq_00177...
# ✅ Berhasil membuat: test_seq_00177.mp4
# Memproses folder: test_seq_00513...
# ✅ Berhasil membuat: test_seq_00513.mp4
# Memproses folder: test_seq_00183...
# ✅ Berhasil membuat: test_seq_00183.mp4
# Memproses folder: test_seq_00148...
# ✅ Berhasil membuat: test_seq_00148.mp4
# Memproses folder: test_seq_00184...
# ✅ Berhasil membuat: test_seq_00184.mp4
# Memproses folder: test_seq_00514...
# ✅ Berhasil membuat: test_seq_00514.mp4
# Memproses folder: test_seq_00170...
# ✅ Berhasil membuat: test_seq_00170.mp4
# Memproses folder: test_seq_00342...
# ✅ Berhasil membuat: test_seq_00342.mp4
# Memproses folder: test_seq_00389...
# ✅ Berhasil membuat: test_seq_00389.mp4
# Memproses folder: test_seq_00380...
# ✅ Berhasil membuat: test_seq_00380.mp4
# Memproses folder: test_seq_00146...
# ✅ Berhasil membuat: test_seq_00146.mp4
# Memproses folder: test_seq_00374...
# ✅ Berhasil membuat: test_seq_00374.mp4
# Memproses folder: test_seq_00522...
# ✅ Berhasil membuat: test_seq_00522.mp4
# Memproses folder: test_seq_00179...
# ✅ Berhasil membuat: test_seq_00179.mp4
# Memproses folder: test_seq_00525...
# ✅ Berhasil membuat: test_seq_00525.mp4
# Memproses folder: test_seq_00373...
# ✅ Berhasil membuat: test_seq_00373.mp4
# Memproses folder: test_seq_00141...
# ✅ Berhasil membuat: test_seq_00141.mp4
# Memproses folder: test_seq_00387...
# ✅ Berhasil membuat: test_seq_00387.mp4
# Memproses folder: test_seq_00579...
# ✅ Berhasil membuat: test_seq_00579.mp4
# Memproses folder: test_seq_00310...
# ✅ Berhasil membuat: test_seq_00310.mp4
# Memproses folder: test_seq_00122...
# ✅ Berhasil membuat: test_seq_00122.mp4
# Memproses folder: test_seq_00546...
# ✅ Berhasil membuat: test_seq_00546.mp4
# Memproses folder: test_seq_00328...
# ✅ Berhasil membuat: test_seq_00328.mp4
# Memproses folder: test_seq_00541...
# ✅ Berhasil membuat: test_seq_00541.mp4
# Memproses folder: test_seq_00125...
# ✅ Berhasil membuat: test_seq_00125.mp4
# Memproses folder: test_seq_00317...
# ✅ Berhasil membuat: test_seq_00317.mp4
# Memproses folder: test_seq_00548...
# ✅ Berhasil membuat: test_seq_00548.mp4
# Memproses folder: test_seq_00113...
# ✅ Berhasil membuat: test_seq_00113.mp4
# Memproses folder: test_seq_00321...
# ✅ Berhasil membuat: test_seq_00321.mp4
# Memproses folder: test_seq_00577...
# ✅ Berhasil membuat: test_seq_00577.mp4
# Memproses folder: test_seq_00583...
# ✅ Berhasil membuat: test_seq_00583.mp4
# Memproses folder: test_seq_00319...
# ✅ Berhasil membuat: test_seq_00319.mp4
# Memproses folder: test_seq_00584...
# ✅ Berhasil membuat: test_seq_00584.mp4
# Memproses folder: test_seq_00570...
# ✅ Berhasil membuat: test_seq_00570.mp4
# Memproses folder: test_seq_00326...
# ✅ Berhasil membuat: test_seq_00326.mp4
# Memproses folder: test_seq_00114...
# ✅ Berhasil membuat: test_seq_00114.mp4
# Memproses folder: test_seq_00386...
# ✅ Berhasil membuat: test_seq_00386.mp4
# Memproses folder: test_seq_00524...
# ✅ Berhasil membuat: test_seq_00524.mp4
# Memproses folder: test_seq_00140...
# ✅ Berhasil membuat: test_seq_00140.mp4
# Memproses folder: test_seq_00372...
# ✅ Berhasil membuat: test_seq_00372.mp4
# Memproses folder: test_seq_00375...
# ✅ Berhasil membuat: test_seq_00375.mp4
# Memproses folder: test_seq_00147...
# ✅ Berhasil membuat: test_seq_00147.mp4
# Memproses folder: test_seq_00523...
# ✅ Berhasil membuat: test_seq_00523.mp4
# Memproses folder: test_seq_00381...
# ✅ Berhasil membuat: test_seq_00381.mp4
# Memproses folder: test_seq_00178...
# ✅ Berhasil membuat: test_seq_00178.mp4
# Memproses folder: test_seq_00515...
# ✅ Berhasil membuat: test_seq_00515.mp4
# Memproses folder: test_seq_00343...
# ✅ Berhasil membuat: test_seq_00343.mp4
# Memproses folder: test_seq_00171...
# ✅ Berhasil membuat: test_seq_00171.mp4
# Memproses folder: test_seq_00185...
# ✅ Berhasil membuat: test_seq_00185.mp4
# Memproses folder: test_seq_00388...
# ✅ Berhasil membuat: test_seq_00388.mp4
# Memproses folder: test_seq_00182...
# ✅ Berhasil membuat: test_seq_00182.mp4
# Memproses folder: test_seq_00176...
# ✅ Berhasil membuat: test_seq_00176.mp4
# Memproses folder: test_seq_00344...
# ✅ Berhasil membuat: test_seq_00344.mp4
# Memproses folder: test_seq_00512...
# ✅ Berhasil membuat: test_seq_00512.mp4
# Memproses folder: test_seq_00149...
# ✅ Berhasil membuat: test_seq_00149.mp4
# Memproses folder: test_seq_00359...
# ✅ Berhasil membuat: test_seq_00359.mp4
# Memproses folder: test_seq_00392...
# ✅ Berhasil membuat: test_seq_00392.mp4
# Memproses folder: test_seq_00530...
# ✅ Berhasil membuat: test_seq_00530.mp4
# Memproses folder: test_seq_00366...
# ✅ Berhasil membuat: test_seq_00366.mp4
# Memproses folder: test_seq_00154...
# ✅ Berhasil membuat: test_seq_00154.mp4
# Memproses folder: test_seq_00508...
# ✅ Berhasil membuat: test_seq_00508.mp4
# Memproses folder: test_seq_00198...
# ✅ Berhasil membuat: test_seq_00198.mp4
# Memproses folder: test_seq_00153...
# ✅ Berhasil membuat: test_seq_00153.mp4
# Memproses folder: test_seq_00361...
# ✅ Berhasil membuat: test_seq_00361.mp4
# Memproses folder: test_seq_00537...
# ✅ Berhasil membuat: test_seq_00537.mp4
# Memproses folder: test_seq_00395...
# ✅ Berhasil membuat: test_seq_00395.mp4
# Memproses folder: test_seq_00368...
# ✅ Berhasil membuat: test_seq_00368.mp4
# Memproses folder: test_seq_00501...
# ✅ Berhasil membuat: test_seq_00501.mp4
# Memproses folder: test_seq_00165...
# ✅ Berhasil membuat: test_seq_00165.mp4
# Memproses folder: test_seq_00357...
# ✅ Berhasil membuat: test_seq_00357.mp4
# Memproses folder: test_seq_00191...
# ✅ Berhasil membuat: test_seq_00191.mp4
# Memproses folder: test_seq_00539...
# ✅ Berhasil membuat: test_seq_00539.mp4
# Memproses folder: test_seq_00196...
# ✅ Berhasil membuat: test_seq_00196.mp4
# Memproses folder: test_seq_00350...
# ✅ Berhasil membuat: test_seq_00350.mp4
# Memproses folder: test_seq_00162...
# ✅ Berhasil membuat: test_seq_00162.mp4
# Memproses folder: test_seq_00506...
# ✅ Berhasil membuat: test_seq_00506.mp4
# Memproses folder: test_seq_00136...
# ✅ Berhasil membuat: test_seq_00136.mp4
# Memproses folder: test_seq_00304...
# ✅ Berhasil membuat: test_seq_00304.mp4
# Memproses folder: test_seq_00552...
# ✅ Berhasil membuat: test_seq_00552.mp4
# Memproses folder: test_seq_00599...
# ✅ Berhasil membuat: test_seq_00599.mp4
# Memproses folder: test_seq_00109...
# ✅ Berhasil membuat: test_seq_00109.mp4
# Memproses folder: test_seq_00555...
# ✅ Berhasil membuat: test_seq_00555.mp4
# Memproses folder: test_seq_00303...
# ✅ Berhasil membuat: test_seq_00303.mp4
# Memproses folder: test_seq_00131...
# ✅ Berhasil membuat: test_seq_00131.mp4
# Memproses folder: test_seq_00335...
# ✅ Berhasil membuat: test_seq_00335.mp4
# Memproses folder: test_seq_00107...
# ✅ Berhasil membuat: test_seq_00107.mp4
# Memproses folder: test_seq_00563...
# ✅ Berhasil membuat: test_seq_00563.mp4
# Memproses folder: test_seq_00597...
# ✅ Berhasil membuat: test_seq_00597.mp4
# Memproses folder: test_seq_00138...
# ✅ Berhasil membuat: test_seq_00138.mp4
# Memproses folder: test_seq_00590...
# ✅ Berhasil membuat: test_seq_00590.mp4
# Memproses folder: test_seq_00564...
# ✅ Berhasil membuat: test_seq_00564.mp4
# Memproses folder: test_seq_00100...
# ✅ Berhasil membuat: test_seq_00100.mp4
# Memproses folder: test_seq_00332...
# ✅ Berhasil membuat: test_seq_00332.mp4
# Memproses folder: test_seq_00538...
# ✅ Berhasil membuat: test_seq_00538.mp4
# Memproses folder: test_seq_00163...
# ✅ Berhasil membuat: test_seq_00163.mp4
# Memproses folder: test_seq_00351...
# ✅ Berhasil membuat: test_seq_00351.mp4
# Memproses folder: test_seq_00507...
# ✅ Berhasil membuat: test_seq_00507.mp4
# Memproses folder: test_seq_00197...
# ✅ Berhasil membuat: test_seq_00197.mp4
# Memproses folder: test_seq_00369...
# ✅ Berhasil membuat: test_seq_00369.mp4
# Memproses folder: test_seq_00190...
# ✅ Berhasil membuat: test_seq_00190.mp4
# Memproses folder: test_seq_00500...
# ✅ Berhasil membuat: test_seq_00500.mp4
# Memproses folder: test_seq_00356...
# ✅ Berhasil membuat: test_seq_00356.mp4
# Memproses folder: test_seq_00164...
# ✅ Berhasil membuat: test_seq_00164.mp4
# Memproses folder: test_seq_00199...
# ✅ Berhasil membuat: test_seq_00199.mp4
# Memproses folder: test_seq_00509...
# ✅ Berhasil membuat: test_seq_00509.mp4
# Memproses folder: test_seq_00394...
# ✅ Berhasil membuat: test_seq_00394.mp4
# Memproses folder: test_seq_00360...
# ✅ Berhasil membuat: test_seq_00360.mp4
# Memproses folder: test_seq_00152...
# ✅ Berhasil membuat: test_seq_00152.mp4
# Memproses folder: test_seq_00536...
# ✅ Berhasil membuat: test_seq_00536.mp4
# Memproses folder: test_seq_00358...
# ✅ Berhasil membuat: test_seq_00358.mp4
# Memproses folder: test_seq_00531...
# ✅ Berhasil membuat: test_seq_00531.mp4
# Memproses folder: test_seq_00155...
# ✅ Berhasil membuat: test_seq_00155.mp4
# Memproses folder: test_seq_00367...
# ✅ Berhasil membuat: test_seq_00367.mp4
# Memproses folder: test_seq_00393...
# ✅ Berhasil membuat: test_seq_00393.mp4
# Memproses folder: test_seq_00565...
# ✅ Berhasil membuat: test_seq_00565.mp4
# Memproses folder: test_seq_00333...
# ✅ Berhasil membuat: test_seq_00333.mp4
# Memproses folder: test_seq_00101...
# ✅ Berhasil membuat: test_seq_00101.mp4
# Memproses folder: test_seq_00591...
# ✅ Berhasil membuat: test_seq_00591.mp4
# Memproses folder: test_seq_00596...
# ✅ Berhasil membuat: test_seq_00596.mp4
# Memproses folder: test_seq_00106...
# ✅ Berhasil membuat: test_seq_00106.mp4
# Memproses folder: test_seq_00334...
# ✅ Berhasil membuat: test_seq_00334.mp4
# Memproses folder: test_seq_00562...
# ✅ Berhasil membuat: test_seq_00562.mp4
# Memproses folder: test_seq_00139...
# ✅ Berhasil membuat: test_seq_00139.mp4
# Memproses folder: test_seq_00554...
# ✅ Berhasil membuat: test_seq_00554.mp4
# Memproses folder: test_seq_00130...
# ✅ Berhasil membuat: test_seq_00130.mp4
# Memproses folder: test_seq_00302...
# ✅ Berhasil membuat: test_seq_00302.mp4
# Memproses folder: test_seq_00305...
# ✅ Berhasil membuat: test_seq_00305.mp4
# Memproses folder: test_seq_00137...
# ✅ Berhasil membuat: test_seq_00137.mp4
# Memproses folder: test_seq_00553...
# ✅ Berhasil membuat: test_seq_00553.mp4
# Memproses folder: test_seq_00108...
# ✅ Berhasil membuat: test_seq_00108.mp4
# Memproses folder: test_seq_00598...
# ✅ Berhasil membuat: test_seq_00598.mp4
# Memproses folder: test_seq_00248...
# ✅ Berhasil membuat: test_seq_00248.mp4
# Memproses folder: test_seq_00283...
# ✅ Berhasil membuat: test_seq_00283.mp4
# Memproses folder: test_seq_00421...
# ✅ Berhasil membuat: test_seq_00421.mp4
# Memproses folder: test_seq_00277...
# ✅ Berhasil membuat: test_seq_00277.mp4
# Memproses folder: test_seq_00045...
# ✅ Berhasil membuat: test_seq_00045.mp4
# Memproses folder: test_seq_00419...
# ✅ Berhasil membuat: test_seq_00419.mp4
# Memproses folder: test_seq_00089...
# ✅ Berhasil membuat: test_seq_00089.mp4
# Memproses folder: test_seq_00042...
# ✅ Berhasil membuat: test_seq_00042.mp4
# Memproses folder: test_seq_00270...
# ✅ Berhasil membuat: test_seq_00270.mp4
# Memproses folder: test_seq_00426...
# ✅ Berhasil membuat: test_seq_00426.mp4
# Memproses folder: test_seq_00284...
# ✅ Berhasil membuat: test_seq_00284.mp4
# Memproses folder: test_seq_00279...
# ✅ Berhasil membuat: test_seq_00279.mp4
# Memproses folder: test_seq_00410...
# ✅ Berhasil membuat: test_seq_00410.mp4
# Memproses folder: test_seq_00074...
# ✅ Berhasil membuat: test_seq_00074.mp4
# Memproses folder: test_seq_00246...
# ✅ Berhasil membuat: test_seq_00246.mp4
# Memproses folder: test_seq_00080...
# ✅ Berhasil membuat: test_seq_00080.mp4
# Memproses folder: test_seq_00428...
# ✅ Berhasil membuat: test_seq_00428.mp4
# Memproses folder: test_seq_00087...
# ✅ Berhasil membuat: test_seq_00087.mp4
# Memproses folder: test_seq_00241...
# ✅ Berhasil membuat: test_seq_00241.mp4
# Memproses folder: test_seq_00073...
# ✅ Berhasil membuat: test_seq_00073.mp4
# Memproses folder: test_seq_00417...
# ✅ Berhasil membuat: test_seq_00417.mp4
# Memproses folder: test_seq_00027...
# ✅ Berhasil membuat: test_seq_00027.mp4
# Memproses folder: test_seq_00215...
# ✅ Berhasil membuat: test_seq_00215.mp4
# Memproses folder: test_seq_00443...
# ✅ Berhasil membuat: test_seq_00443.mp4
# Memproses folder: test_seq_00488...
# ✅ Berhasil membuat: test_seq_00488.mp4
# Memproses folder: test_seq_00018...
# ✅ Berhasil membuat: test_seq_00018.mp4
# Memproses folder: test_seq_00444...
# ✅ Berhasil membuat: test_seq_00444.mp4
# Memproses folder: test_seq_00212...
# ✅ Berhasil membuat: test_seq_00212.mp4
# Memproses folder: test_seq_00020...
# ✅ Berhasil membuat: test_seq_00020.mp4
# Memproses folder: test_seq_00224...
# ✅ Berhasil membuat: test_seq_00224.mp4
# Memproses folder: test_seq_00016...
# ✅ Berhasil membuat: test_seq_00016.mp4
# Memproses folder: test_seq_00472...
# ✅ Berhasil membuat: test_seq_00472.mp4
# Memproses folder: test_seq_00486...
# ✅ Berhasil membuat: test_seq_00486.mp4
# Memproses folder: test_seq_00029...
# ✅ Berhasil membuat: test_seq_00029.mp4
# Memproses folder: test_seq_00481...
# ✅ Berhasil membuat: test_seq_00481.mp4
# Memproses folder: test_seq_00475...
# ✅ Berhasil membuat: test_seq_00475.mp4
# Memproses folder: test_seq_00011...
# ✅ Berhasil membuat: test_seq_00011.mp4
# Memproses folder: test_seq_00223...
# ✅ Berhasil membuat: test_seq_00223.mp4
# Memproses folder: test_seq_00429...
# ✅ Berhasil membuat: test_seq_00429.mp4
# Memproses folder: test_seq_00072...
# ✅ Berhasil membuat: test_seq_00072.mp4
# Memproses folder: test_seq_00240...
# ✅ Berhasil membuat: test_seq_00240.mp4
# Memproses folder: test_seq_00416...
# ✅ Berhasil membuat: test_seq_00416.mp4
# Memproses folder: test_seq_00086...
# ✅ Berhasil membuat: test_seq_00086.mp4
# Memproses folder: test_seq_00278...
# ✅ Berhasil membuat: test_seq_00278.mp4
# Memproses folder: test_seq_00081...
# ✅ Berhasil membuat: test_seq_00081.mp4
# Memproses folder: test_seq_00411...
# ✅ Berhasil membuat: test_seq_00411.mp4
# Memproses folder: test_seq_00247...
# ✅ Berhasil membuat: test_seq_00247.mp4
# Memproses folder: test_seq_00075...
# ✅ Berhasil membuat: test_seq_00075.mp4
# Memproses folder: test_seq_00088...
# ✅ Berhasil membuat: test_seq_00088.mp4
# Memproses folder: test_seq_00418...
# ✅ Berhasil membuat: test_seq_00418.mp4
# Memproses folder: test_seq_00285...
# ✅ Berhasil membuat: test_seq_00285.mp4
# Memproses folder: test_seq_00271...
# ✅ Berhasil membuat: test_seq_00271.mp4
# Memproses folder: test_seq_00043...
# ✅ Berhasil membuat: test_seq_00043.mp4
# Memproses folder: test_seq_00427...
# ✅ Berhasil membuat: test_seq_00427.mp4
# Memproses folder: test_seq_00249...
# ✅ Berhasil membuat: test_seq_00249.mp4
# Memproses folder: test_seq_00420...
# ✅ Berhasil membuat: test_seq_00420.mp4
# Memproses folder: test_seq_00044...
# ✅ Berhasil membuat: test_seq_00044.mp4
# Memproses folder: test_seq_00276...
# ✅ Berhasil membuat: test_seq_00276.mp4
# Memproses folder: test_seq_00282...
# ✅ Berhasil membuat: test_seq_00282.mp4
# Memproses folder: test_seq_00474...
# ✅ Berhasil membuat: test_seq_00474.mp4
# Memproses folder: test_seq_00222...
# ✅ Berhasil membuat: test_seq_00222.mp4
# Memproses folder: test_seq_00010...
# ✅ Berhasil membuat: test_seq_00010.mp4
# Memproses folder: test_seq_00480...
# ✅ Berhasil membuat: test_seq_00480.mp4
# Memproses folder: test_seq_00487...
# ✅ Berhasil membuat: test_seq_00487.mp4
# Memproses folder: test_seq_00017...
# ✅ Berhasil membuat: test_seq_00017.mp4
# Memproses folder: test_seq_00225...
# ✅ Berhasil membuat: test_seq_00225.mp4
# Memproses folder: test_seq_00473...
# ✅ Berhasil membuat: test_seq_00473.mp4
# Memproses folder: test_seq_00028...
# ✅ Berhasil membuat: test_seq_00028.mp4
# Memproses folder: test_seq_00445...
# ✅ Berhasil membuat: test_seq_00445.mp4
# Memproses folder: test_seq_00021...
# ✅ Berhasil membuat: test_seq_00021.mp4
# Memproses folder: test_seq_00213...
# ✅ Berhasil membuat: test_seq_00213.mp4
# Memproses folder: test_seq_00214...
# ✅ Berhasil membuat: test_seq_00214.mp4
# Memproses folder: test_seq_00026...
# ✅ Berhasil membuat: test_seq_00026.mp4
# Memproses folder: test_seq_00442...
# ✅ Berhasil membuat: test_seq_00442.mp4
# Memproses folder: test_seq_00019...
# ✅ Berhasil membuat: test_seq_00019.mp4
# Memproses folder: test_seq_00489...
# ✅ Berhasil membuat: test_seq_00489.mp4
# --------------------------------------------------
# Proses Konversi Selesai. Video-video baru tersimpan di: Data Slayer 3/test_video

# %%
import os
import pandas as pd

# Direktori hasil konversi video dari script sebelumnya
OUTPUT_DIR = "Data Slayer 3/test_video" 
METADATA_FILE = "metadata_test.csv"

data = []

# Loop melalui semua file video di direktori output
for video_filename in os.listdir(OUTPUT_DIR):
    # Pastikan itu adalah file video .mp4
    if video_filename.endswith(".mp4"):
        
        # 1. video_path (Path relatif dari root)
        video_path = os.path.join(OUTPUT_DIR, video_filename).replace("\\", "/") 
        
        # 2. subject_id
        # subject_id adalah nama folder sequence (misal: test_seq_00001)
        # Hapus ekstensi .mp4 dari nama file
        subject_id = video_filename.replace(".mp4", "")
        
        # 3. label
        # !!! PERHATIAN PENTING !!!
        # Data test (pengujian) biasanya tidak memiliki label (ground truth)
        # Jika model Anda adalah klasifikasi, label untuk data test biasanya diisi dengan nilai placeholder (misal: -1, 0, atau "unknown")
        # Sesuaikan 'unknown' di bawah ini dengan placeholder yang Anda butuhkan.
        label = "unknown" 
        
        # Jika Anda tahu bahwa subject_id mengandung label di dalamnya (misalnya 'angry_001'), 
        # Anda bisa mengekstraknya di sini, tapi untuk saat ini kita asumsikan 'unknown'.

        data.append({
            'subject_id': subject_id,
            'video_path': video_path,
            'label': label
        })

# Buat DataFrame dan simpan ke CSV
df = pd.DataFrame(data)
df.to_csv(METADATA_FILE, index=False)

print("-" * 50)
print(f"✅ File metadata berhasil dibuat di: {METADATA_FILE}")
print(f"Total {len(df)} baris (video) telah ditambahkan.")
print("Berikut adalah 5 baris pertama:")
print(df.head())
# Out:
# --------------------------------------------------
# ✅ File metadata berhasil dibuat di: metadata_test.csv
# Total 602 baris (video) telah ditambahkan.
# Berikut adalah 5 baris pertama:
#        subject_id                                   video_path    label
# 0  test_seq_00264  Data Slayer 3/test_video/test_seq_00264.mp4  unknown
# 1  test_seq_00502  Data Slayer 3/test_video/test_seq_00502.mp4  unknown
# 2  test_seq_00516  Data Slayer 3/test_video/test_seq_00516.mp4  unknown
# 3  test_seq_00270  Data Slayer 3/test_video/test_seq_00270.mp4  unknown
# 4  test_seq_00258  Data Slayer 3/test_video/test_seq_00258.mp4  unknown
